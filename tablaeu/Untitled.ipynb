# %%
import pandas as pd
from functools import reduce

df = pd.read_excel('assignment-01-data-unformated.xlsx')
df = df.reset_index(drop=False)

dfl = list()
col = ['soft corals','sea fans','blue corals','hard corals','sea pens']
for x in range(0,5):
    df1 = df.iloc[:,:11]
    df1.columns = df1.iloc[0]
    df1 = df1[1:]
    res = pd.melt(df1, id_vars=['name','longitude','latitude'], var_name=['Year'])
    res = res.rename(columns = {'value':col[x]})
    dfl.append(res)
    df.drop(df.columns[[3,4,5,6,7,8,9,10]], axis=1, inplace=True)
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['name','longitude','latitude','Year'],
                                            how='outer'), dfl)
data = pd.melt(df_merged, id_vars=['name','longitude','latitude','Year'], var_name=['Corals'])
# Out:
#   level_0    level_1   level_2  soft corals  Unnamed: 1  Unnamed: 2  \
# 0    name  longitude  latitude    2017.0000   2016.0000   2015.0000
# 1  site01    143.515   -11.843       0.8387      0.8021      0.7534
# 2  site02    147.898    18.937       0.2123      0.1923      0.1721
# 3  site03    144.081   -10.321       0.7534      0.6023      0.3721
# 4  site04    150.444   -20.414       0.1245      0.1178      0.1134
# 5  site05    143.786   -13.107       0.9423      0.9123      0.7623
# 6  site06    146.589   -17.981          NaN         NaN         NaN
# 7  site07    145.043   -14.383       0.6789      0.6078      0.5876
# 8  site08    145.715   -16.091       0.6523      0.6321      0.6012
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6     ...       Unnamed: 30  \
# 0   2014.0000   2013.0000   2012.0000   2011.0000     ...         2011.0000
# 1      0.7499      0.5770      0.5643      0.5543     ...            0.1934
# ...

# %%
df.loc[2,'level_2'] = -18.937
df
# Out:
#   level_0    level_1   level_2  soft corals  Unnamed: 1  Unnamed: 2  \
# 0    name  longitude  latitude    2017.0000   2016.0000   2015.0000
# 1  site01    143.515   -11.843       0.8387      0.8021      0.7534
# 2  site02    147.898   -18.937       0.2123      0.1923      0.1721
# 3  site03    144.081   -10.321       0.7534      0.6023      0.3721
# 4  site04    150.444   -20.414       0.1245      0.1178      0.1134
# 5  site05    143.786   -13.107       0.9423      0.9123      0.7623
# 6  site06    146.589   -17.981          NaN         NaN         NaN
# 7  site07    145.043   -14.383       0.6789      0.6078      0.5876
# 8  site08    145.715   -16.091       0.6523      0.6321      0.6012
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6     ...       Unnamed: 30  \
# 0   2014.0000   2013.0000   2012.0000   2011.0000     ...         2011.0000
# 1      0.7499      0.5770      0.5643      0.5543     ...            0.1934
# ...

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['name','longitude','latitude','Year'],
                                            how='outer'), dfl)
data = pd.melt(df_merged, id_vars=['name','longitude','latitude','Year'], var_name=['Corals'])

# %%
data = pd.melt(df_merged, id_vars=['name','longitude','latitude','Year'], var_name=['Corals'])
for x in range(320):
    data.loc[x,'value'] = data.loc[x,'value']*100
data
# Out:
#        name longitude latitude  Year       Corals  value
# 0    site01   143.515  -11.843  2017  soft corals  83.87
# 1    site02   147.898  -18.937  2017  soft corals  21.23
# 2    site03   144.081  -10.321  2017  soft corals  75.34
# 3    site04   150.444  -20.414  2017  soft corals  12.45
# 4    site05   143.786  -13.107  2017  soft corals  94.23
# 5    site06   146.589  -17.981  2017  soft corals    NaN
# 6    site07   145.043  -14.383  2017  soft corals  67.89
# 7    site08   145.715  -16.091  2017  soft corals  65.23
# 8    site01   143.515  -11.843  2016  soft corals  80.21
# 9    site02   147.898  -18.937  2016  soft corals  19.23
# 10   site03   144.081  -10.321  2016  soft corals  60.23
# 11   site04   150.444  -20.414  2016  soft corals  11.78
# 12   site05   143.786  -13.107  2016  soft corals  91.23
# 13   site06   146.589  -17.981  2016  soft corals    NaN
# 14   site07   145.043  -14.383  2016  soft corals  60.78
# ...

# %%
from pandas import ExcelWriter

writer = ExcelWriter('Transaction_Summary_Oct_19_-_March_20201.xlsx')
df.to_excel(writer)
writer.save()

# %%
data
# Out:
#        name longitude latitude  Year       Corals  value
# 0    site01   143.515  -11.843  2017  soft corals  83.87
# 1    site02   147.898  -18.937  2017  soft corals  21.23
# 2    site03   144.081  -10.321  2017  soft corals  75.34
# 3    site04   150.444  -20.414  2017  soft corals  12.45
# 4    site05   143.786  -13.107  2017  soft corals  94.23
# 5    site06   146.589  -17.981  2017  soft corals    NaN
# 6    site07   145.043  -14.383  2017  soft corals  67.89
# 7    site08   145.715  -16.091  2017  soft corals  65.23
# 8    site01   143.515  -11.843  2016  soft corals  80.21
# 9    site02   147.898  -18.937  2016  soft corals  19.23
# 10   site03   144.081  -10.321  2016  soft corals  60.23
# 11   site04   150.444  -20.414  2016  soft corals  11.78
# 12   site05   143.786  -13.107  2016  soft corals  91.23
# 13   site06   146.589  -17.981  2016  soft corals    NaN
# 14   site07   145.043  -14.383  2016  soft corals  60.78
# ...

# %%
import pandas as pd
df = pd.read_excel('Transaction_Summary_Oct_19_-_March_2020.xlsx')

# %%
df
# Out:
#               Unnamed: 0                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# 6                    NaN                                                NaN
# 7                    NaN                                                NaN
# 8                    NaN                                                NaN
# 9                    NaN                                                NaN
# 10                   NaN                                                NaN
# ...

# %%
df.iloc[16,2]
# Out:
# -152

# %%
df["Unnamed"]= df['Unnamed: 2'].apply(lambda x: x if type(x)=='str' else abs(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-526a2116a232> in <module>
# ----> 1 df["Unnamed"]= df['Unnamed: 2'].apply(lambda x: x if type(x)=='str' else abs(x))
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-71-526a2116a232> in <lambda>(x)
# ----> 1 df["Unnamed"]= df['Unnamed: 2'].apply(lambda x: x if type(x)=='str' else abs(x))
#
# TypeError: bad operand type for abs(): 'str'

# %%
for x in range(125):
    if type(df.iloc[x,2]) != str:
        df.iloc[x,2] = abs(df.iloc[x,2])

# %%
df
# Out:
#               Unnamed: 0                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# 6                    NaN                                                NaN
# 7                    NaN                                                NaN
# 8                    NaN                                                NaN
# 9                    NaN                                                NaN
# 10                   NaN                                                NaN
# ...
